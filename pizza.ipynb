# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/workspaces/Ravi-kumar-svce/DOC-20221023-WA0000.csv")
df.head(67)
# Out:
#         ROLLNO  COURSE BRANCH Unnamed: 3  Unnamed: 4     YEAR  \
# 0   21BF1A3201  B.Tech    CSD        NaN         NaN  2021-25
# 1   21BF1A3202  B.Tech    CSD        NaN         NaN  2021-25
# 2   21BF1A3203  B.Tech   CSD$        NaN         NaN  2021-25
# 3   21BF1A3204  B.Tech    CSD        NaN         NaN  2021-25
# 4   21BF1A3205  B.Tech    CSD        NaN         NaN  2021-25
# ..         ...     ...    ...        ...         ...      ...
# 62  21BF1A3261  B.Tech    CSD        NaN         NaN  2021-25
# 63  21BF1A3262  B.Tech    CSD        NaN         NaN  2021-25
# 64  21BF1A3263  B.Tech    CSD        NaN         NaN  2021-25
# 65  21BF1A3264  B.Tech    CSD        NaN         NaN  2021-25
# 66  21BF1A3265  B.Tech    CSD        NaN         NaN  2021-25
#
#                          NAME                Father Name  \
# 0                   A. Charan           A. Lakshmi pathi
# 1              A.Lolitha sree       A.venkatramana Reddy
# ...
