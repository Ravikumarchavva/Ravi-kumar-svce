# %% [markdown]
# <a href="https://colab.research.google.com/github/Ravikumarchavva/Ravi-kumar-svce/blob/main/Jup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /workspaces/Ravi-kumar-svce/Pandas_module.ipynb Cell 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://codespaces%2Bravikumarchavva-fictional-disco-r4p6v96979f4q5/workspaces/Ravi-kumar-svce/Pandas_module.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> from google.colab import drive
#       <a href='vscode-notebook-cell://codespaces%2Bravikumarchavva-fictional-disco-r4p6v96979f4q5/workspaces/Ravi-kumar-svce/Pandas_module.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
import pandas as pd
Df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/DOC-20221023-WA0000.csv")
Df.shape
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /workspaces/Ravi-kumar-svce/Pandas_module.ipynb Cell 3 in <cell line: 2>()
#       <a href='vscode-notebook-cell://codespaces%2Bravikumarchavva-fictional-disco-r4p6v96979f4q5/workspaces/Ravi-kumar-svce/Pandas_module.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> import pandas as pd
# ----> <a href='vscode-notebook-cell://codespaces%2Bravikumarchavva-fictional-disco-r4p6v96979f4q5/workspaces/Ravi-kumar-svce/Pandas_module.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> Df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/DOC-20221023-WA0000.csv")
#       <a href='vscode-notebook-cell://codespaces%2Bravikumarchavva-fictional-disco-r4p6v96979f4q5/workspaces/Ravi-kumar-svce/Pandas_module.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> Df.shape
#
# ...

# %%
Df.drop(index=Df.index[69:362], axis=0, inplace=True)

# %%
Df.drop(['BRANCH','COURSE','YEAR','PHOTO','BARCODE','x','Unnamed: 3','Unnamed: 4','Unnamed: 14','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21','Unnamed: 22','Unnamed: 23'],axis=1,inplace=True)
Df.rename(columns={'Unnamed: 12':'DOB'},inplace=True)

# %%
Df.shape
Df
# Out:
#         ROLLNO                       NAME                Father Name  \
# 0   21BF1A3201                  A. Charan           A. Lakshmi pathi
# 1   21BF1A3202             A.Lolitha sree       A.venkatramana Reddy
# 2   21BF1A3203                   A.Rohini             A.Vijaya kumar
# 3   21BF1A3204  Akkayyagari Venkateswarlu             A.Subrahmanyam
# 4   21BF1A3205      A.Tharun Kumar Reddy     A.Venkata Ramana Reddy
# ..         ...                        ...                        ...
# 64  21BF1A3263         Vemuri Murali Neha        Vemuri Murali Naidu
# 65  21BF1A3264         Vutukuri Varshitha    Vutukuri Venkata Ramesh
# 66  21BF1A3265      Yekabote Soma Shekhar            Yekabote Ramesh
# 67  21BF1A3266               Y.Monikamani                Y.Subramani
# 68  21BF1A3215       Dandu  Bharath kumar             Dandu satyanna
#
#                                            Address  \
# 0               1-32 , Jangala palli(v) , Chittoor
# ...
