# %% [markdown]
# <a href="https://colab.research.google.com/github/Ravikumarchavva/Ravi-kumar-svce/blob/main/copy_of_mpl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#                                                       **lok sabha elections**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np

# %%
voters=np.array([160275056,182075041,119896443,152697161,151536802,194263915,202752893,256294963,309050495,285856465,343308090,375441739,371669104,389342364,417087209,553801801,612081902])
electors=np.array([237041443,265241358,216361569,250207401,274189132,321174327,356205329,400375333,498906129,511533598,592572288,605880192,619536847,671487930,716985104,834101479,880532803])
years=np.array([1952,1957,1962,1967,1971,1977,1980,1984,1989,1991,1996,1998,1999,2004,2009,2014,2019])

# %%
plt.plot(years,electors,'yD-',label="electors")
plt.plot(years,voters,'v-',label="voters")
plt.legend()
plt.xlabel('years')
plt.ylabel("voting")
plt.show()
